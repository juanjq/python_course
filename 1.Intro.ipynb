# %% [markdown]
# # <font color='gold'>**Main code structure**</font>

# %% [markdown]
# The structre to make a program, where the main file is called `main.py`

# %%
#imports....

#def functions     
    
def main():
  pass

if __name__ == "__main__":
    main()

# %% [markdown]
# #<font color='gold'>**Creating lists**</font>

# %% [markdown]
# * **Creating lists with functions easily with `lambda` and `map`**

# %%
squares=list(map(lambda x: x**2, array))

evens=list(map(lambda x: x%2==0, array))

# %% [markdown]
# # <font color='gold'>**Import `.py` from internet**</font>

# %% [markdown]
# For importing packages that are uploaded to internet, for example charge a gist from github, where the direction `'https://gist.githubusercontent.com/juanjq/.../raw/...'` of the folder on github and the archive named in this case `plt_config.py`

# %%
import httpimport

with httpimport.remote_repo(['plt_config'], 'https://gist.githubusercontent.com/juanjq/447a0de06d29fa21cd6c822ec2801d4a/raw/ed0b5c110df5b4bb71f63b1e642446386f588b8b'):
     import plt_config

# %% [markdown]
# Matplotlibcontext for printing with selected configurations.
#
# My configurations can be imported from a package.

# %%
import httpimport
import matplotlib.pyplot as plt

with httpimport.remote_repo(['plt_config'], 'https://gist.githubusercontent.com/juanjq/447a0de06d29fa21cd6c822ec2801d4a/raw/ed0b5c110df5b4bb71f63b1e642446386f588b8b'):
     import plt_config

# %% [markdown]
# * **Set the context to the configured**

# %%
plt_config.params()

# %% [markdown]
# * **Set the context to default**

# %%
plt_config.default()

# %% [markdown]
# For completitude this is the configuration

# %%
#fontsize
plt.rcParams['font.size'] = 18   
#figure size
plt.rcParams['figure.figsize'] = 16,9    
#LaTex font
plt.rcParams['mathtext.fontset'] = 'custom'
plt.rcParams['mathtext.rm'] = 'Bitstream Vera Sans'
plt.rcParams['mathtext.it'] = 'Bitstream Vera Sans:italic'
plt.rcParams['mathtext.bf'] = 'Bitstream Vera Sans:bold'
plt.rcParams['mathtext.fontset'] = 'stix'
plt.rcParams['font.family'] = 'STIXGeneral'
#ticks
plt.rcParams["xtick.direction"] = "in"
plt.rcParams["ytick.direction"] = "in"
plt.rcParams['xtick.top'] = True
plt.rcParams['ytick.right'] = True
plt.rcParams['xtick.minor.visible'] = True
plt.rcParams['ytick.minor.visible'] = True
plt.rcParams['xtick.major.size'] = 8
plt.rcParams['xtick.major.width'] = 2
plt.rcParams['xtick.minor.size'] = 5
plt.rcParams['xtick.minor.width'] = 1
plt.rcParams['ytick.major.size'] = 8
plt.rcParams['ytick.major.width'] = 2
plt.rcParams['ytick.minor.size'] = 5
plt.rcParams['ytick.minor.width'] = 1
#figure
plt.rcParams['figure.facecolor'] = 'w'
plt.rcParams['figure.frameon'] = False
plt.rcParams['figure.dpi'] = 80
plt.rcParams['savefig.dpi'] = 200
plt.rcParams['savefig.format'] = 'pdf'
plt.rcParams['savefig.transparent'] = True
plt.rcParams['figure.dpi'] = 100
#errorbars
plt.rcParams['errorbar.capsize'] = 3
#histograms
plt.rcParams['hist.bins'] = 30
#lines
plt.rcParams['lines.linewidth'] = 1
plt.rcParams['lines.marker'] = None
#axes
plt.rcParams['axes.facecolor'] ='w'
plt.rcParams['axes.edgecolor'] ='k'
plt.rcParams['axes.linewidth'] =1
plt.rcParams['axes.titlesize'] = 18
plt.rcParams['axes.labelsize'] = 18
plt.rcParams['axes.labelcolor'] = 'k'
#grid
plt.rcParams['axes.grid'] =False
plt.rcParams['grid.color'] ='k'
plt.rcParams['grid.linestyle'] ='-'
plt.rcParams['grid.linewidth'] =0.5
plt.rcParams['grid.alpha'] =1
#legend
plt.rcParams['legend.fancybox'] =True
plt.rcParams['legend.fontsize'] =17
plt.rcParams['legend.markerscale'] =1.5
#colors
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=[
    'darkblue','darkviolet','deeppink','crimson','darkorange','gold'])

# %% [markdown]
# * **Now there is a version that only works in a context, i.e. when the identation is closed, the configuration will return to the before configuration**

# %% [markdown]
# #<font color='gold'>**Folders and directories and `.txt`**</font>

# %% [markdown]
# * **Get current directory**
#
# Only works in the `.py` archive not in `.ipynb`. You get a absolute path of folder for example, `'/home/juan/Escriptori/project'`

# %%
'''
import os 

dir_path = os.path.dirname(os.path.realpath(__file__))
'''
# Out:
# '\nimport os \n\ndir_path = os.path.dirname(os.path.realpath(__file__))\n'

# %% [markdown]
# * **Open a `.txt` file**

# %%
'''
file = open('doc.txt', encoding='utf8')
'''
# Out:
# "\nfile = open('doc.txt', encoding='utf8')\n"

# %% [markdown]
# The file is a set of items separated by tabulators, or commas i.e. using `split()`
#
#
# ```
# element 1          element 1,
# element 2          element 2,
# element 3          element 3,
# ...                ...
# ```

# %%
'''
data = file.read()
file.close()
data=data.split('\n')        data=data.split(',')
'''

# %% [markdown]
# * **Import a `.txt` file from internert**

# %%
import urllib

file = urllib.request.urlopen('http://textfiles.com/adventure/aencounter.txt')
text=''
for line in file:
	text = text + line.decode("utf-8")
 
# print(text)

# %% [markdown]
# For importing as a table

# %%
import pandas
url = "http://jse.amstat.org/v22n1/kopcso/BeefDemand.txt"

df = pandas.read_table(url, sep="\t+", engine='python', index_col="Year")

# %% [markdown]
# #<font color='gold'>**Try except pass**</font>

# %% [markdown]
# Use this is some error is going to appear

# %%
try:
  #do something
except:
  pass

# %% [markdown]
# #<font color='gold'>**Randomizers**</font>

# %% [markdown]
# Some ways to work with random quantities

# %% [markdown]
# * **Get a random element of an array**

# %%
'''
import random

random.choice(array)
'''
# Out:
# '\nimport random\n\nrandom.choice(array)\n'

# %% [markdown]
# #<font color='gold'>**Text edit**</font>

# %% [markdown]
# Some features to edit text
#
# * **Replace elements**

# %%
text=text.replace('_','')

# %% [markdown]
# * **Open `.txt` in lines**

# %%
lines = open('directory/doc.txt').readlines()

# %% [markdown]
# #<font color='gold'>**Copy & paste**</font>

# %%
'''
α β Δ ε η μ π ρ σ φ Φ θ ψ Ψ ω Ω Ͳ ∅ ⇒ → ∀ ∃ ∈ ∉ ⊆ ¾ ¼ ½ ² √ ∞ | ≤ ≥ ∇ ∂ ±
'''

# %% [markdown]
# # <font color='gold'>**Rounding and str treatment**</font>

# %% [markdown]
# * **Number rounding**

# %%
#round  (typical rounding)
A=round(10.687383,number_decimals)

#floor value
A=floor(10.6)
#ceil value
A=ceil(10.6)

# %% [markdown]
# * **Number to str**
#
# If we want to mantain a quantity of zeros to the left

# %%
A=0.001

B=str(A).zfill(8)

print(B)
# Out:
# 0000.001
